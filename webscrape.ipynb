# %%
#import dependencies 
import pandas as pd
from bs4 import BeautifulSoup
import requests
import pymongo
from collections import Counter 
from splinter import Browser
executable_path = {"executable_path": "chromedriver.exe"}
browser = Browser("chrome", **executable_path, headless=False)
import time
import matplotlib.pyplot as plt
import sqlalchemy
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data

# %%
# visit the spotify website
url = 'https://open.spotify.com/playlist/2YRe7HRKNRvXdJBp9nXFza'
#call the browers and go to the url
browser.visit(url)

# %%
#grab the value in the browser
spotify_html = browser.html
#convert to a beautiful soup object
spotify_soup = BeautifulSoup(spotify_html, 'html.parser')

# %%
print(spotify_soup)
# Out:
# <html class="no-focus-outline windows" dir="ltr" lang="en"><head>
# <meta charset="utf-8"/>
# <meta content="Spotify's Most Played All-Time [Updated Weekly] | Most Streamed | Top Played | Major Lazer | Drake | Justin Bieber | 200Mil+, a playlist by Ray Fontaine on Spotify" property="og:title"/>
# <meta content="" property="og:description"/>
# <meta content="https://open.spotify.com/playlist/2YRe7HRKNRvXdJBp9nXFza" property="og:url"/>
# <meta content="" property="og:image"/>
# <meta content="music.playlist" property="og:type"/>
# <meta content="https://open.spotify.com/user/1221028518" property="music:creator"/>
# <meta content="591" property="music:song_count"/>
# <meta content="https://open.spotify.com/track/7qiZfU4dY1lWllzX7mPBI3" property="music:song"/>
# <meta content="1" property="music:song:track"/>
# <meta content="https://open.spotify.com/track/12VWzyPDBCc8fqeWCAfNwR" property="music:song"/>
# <meta content="2" property="music:song:track"/>
# ...

# %%
mydivs = spotify_soup.findAll("div", {"class": "tracklist-name ellipsis-one-line"})
mydivs[99]
# Out:
# <div class="tracklist-name ellipsis-one-line" dir="auto">Fast Car</div>

# %%
song_titles = []
for song in mydivs:
    name = song.get_text()
    song_titles.append(name)

# %%
song_titles
# Out:
# ['Shape of You',
#  'One Dance',
#  'Closer (feat. Halsey)',
#  'rockstar (feat. 21 Savage)',
#  'Thinking out Loud',
#  'Lean On',
#  "God's Plan",
#  'Despacito - Remix',
#  'Love Yourself',
#  'Sorry',
#  'Havana (feat. Young Thug)',
#  "Don't Let Me Down (feat. Daya)",
#  'Starboy',
#  'I Took A Pill In Ibiza - Seeb Remix',
#  'New Rules',
#  'Let Me Love You',
#  'Photograph',
#  "Say You Won't Let Go",
#  'Perfect',
#  'HUMBLE.',
#  'Something Just Like This',
#  'Cheap Thrills',
#  'Cold Water',
#  'What Do You Mean?',
#  'XO Tour Llif3',
#  'Stressed Out',
#  'Uptown Funk',
#  'Faded',
#  'Despacito',
#  'Unforgettable',
#  'Thunder',
#  '7 Years',
#  'Take Me to Church',
#  'Believer',
#  'Cheerleader - Felix Jaehn Remix Radio Edit',
#  'Congratulations',
#  'Treat You Better',
#  'Stitches',
#  'CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s "TROLLS")',
#  'This Is What You Came For',
#  'Stay With Me',
#  'Work from Home (feat. Ty Dolla $ign)',
# ...

# %%
#mydivs2 = spotify_soup.findAll("a", {"class": "tracklist-row__artist-name-link"})
#mydivs2

#get second line which includes all artists and album
#mydivs2 = spotify_soup.findAll("div", {"class": "second-line"})
#mydivs2

mydivs2 = spotify_soup.findAll("span", {"class": "TrackListRow__artists ellipsis-one-line"})
mydivs2
# Out:
# [<span class="TrackListRow__artists ellipsis-one-line" dir="auto"><span class="react-contextmenu-wrapper"><span draggable="true"><a class="tracklist-row__artist-name-link" href="/artist/6eUKZXaKkcviH0Ku9w2n3V" tabindex="-1">Ed Sheeran</a></span></span></span>,
#  <span class="TrackListRow__artists ellipsis-one-line" dir="auto"><span class="react-contextmenu-wrapper"><span draggable="true"><a class="tracklist-row__artist-name-link" href="/artist/3TVXtAsR1Inumwj472S9r4" tabindex="-1">Drake</a></span></span>, <span class="react-contextmenu-wrapper"><span draggable="true"><a class="tracklist-row__artist-name-link" href="/artist/3tVQdUvClmAT7URs9V3rsp" tabindex="-1">WizKid</a></span></span>, <span class="react-contextmenu-wrapper"><span draggable="true"><a class="tracklist-row__artist-name-link" href="/artist/77DAFfvm3O9zT5dIoG0eIO" tabindex="-1">Kyla</a></span></span></span>,
# ...

# %%
artist_names = []
for artist in mydivs2:
    name = artist.get_text()
    artist_names.append(name)

# %%
artist_names
# Out:
# ['Ed Sheeran',
#  'Drake, WizKid, Kyla',
#  'The Chainsmokers, Halsey',
#  'Post Malone, 21 Savage',
#  'Ed Sheeran',
#  'Major Lazer, MØ, DJ Snake',
#  'Drake',
#  'Luis Fonsi, Daddy Yankee, Justin Bieber',
#  'Justin Bieber',
#  'Justin Bieber',
#  'Camila Cabello, Young Thug',
#  'The Chainsmokers, Daya',
#  'The Weeknd, Daft Punk',
#  'Mike Posner, Seeb',
#  'Dua Lipa',
#  'DJ Snake, Justin Bieber',
#  'Ed Sheeran',
#  'James Arthur',
#  'Ed Sheeran',
#  'Kendrick Lamar',
#  'The Chainsmokers, Coldplay',
#  'Sia',
#  'Major Lazer, Justin Bieber, MØ',
#  'Justin Bieber',
#  'Lil Uzi Vert',
#  'Twenty One Pilots',
#  'Mark Ronson, Bruno Mars',
#  'Alan Walker',
#  'Luis Fonsi, Daddy Yankee',
#  'French Montana, Swae Lee',
#  'Imagine Dragons',
#  'Lukas Graham',
#  'Hozier',
#  'Imagine Dragons',
#  'OMI',
#  'Post Malone, Quavo',
#  'Shawn Mendes',
#  'Shawn Mendes',
#  'Justin Timberlake',
#  'Calvin Harris, Rihanna',
#  'Sam Smith',
#  'Fifth Harmony, Ty Dolla $ign',
# ...

# %%
>>> keys = artist_names
>>> values = song_titles
>>> dictionary = dict(zip(keys, values))
>>> print(dictionary)
# Out:
# {'Ed Sheeran': 'Perfect', 'Drake, WizKid, Kyla': 'One Dance', 'The Chainsmokers, Halsey': 'Closer (feat. Halsey)', 'Post Malone, 21 Savage': 'rockstar (feat. 21 Savage)', 'Major Lazer, MØ, DJ Snake': 'Lean On', 'Drake': 'In My Feelings', 'Luis Fonsi, Daddy Yankee, Justin Bieber': 'Despacito - Remix', 'Justin Bieber': 'What Do You Mean?', 'Camila Cabello, Young Thug': 'Havana (feat. Young Thug)', 'The Chainsmokers, Daya': "Don't Let Me Down (feat. Daya)", 'The Weeknd, Daft Punk': 'I Feel It Coming', 'Mike Posner, Seeb': 'I Took A Pill In Ibiza - Seeb Remix', 'Dua Lipa': 'IDGAF', 'DJ Snake, Justin Bieber': 'Let Me Love You', 'James Arthur': "Say You Won't Let Go", 'Kendrick Lamar': 'HUMBLE.', 'The Chainsmokers, Coldplay': 'Something Just Like This', 'Sia': 'Chandelier', 'Major Lazer, Justin Bieber, MØ': 'Cold Water', 'Lil Uzi Vert': 'XO Tour Llif3', 'Twenty One Pilots': 'Ride', 'Mark Ronson, Bruno Mars': 'Uptown Funk', 'Alan Walker': 'Faded', 'Luis Fonsi, Daddy Yankee': 'Despacito', 'F
# ...

# %%
# list of strings 
lst = artist_names
# list of int 
lst2 = song_titles
  
# Calling DataFrame constructor after zipping 
# both lists, with columns specified 
df_songs_artists = pd.DataFrame(list(zip(artist_names, song_titles)), 
               columns =['Artist', 'Song']) 
df_songs_artists
# Out:
#                                      Artist  \
# 0                                Ed Sheeran
# 1                       Drake, WizKid, Kyla
# 2                  The Chainsmokers, Halsey
# 3                    Post Malone, 21 Savage
# 4                                Ed Sheeran
# 5                 Major Lazer, MØ, DJ Snake
# 6                                     Drake
# 7   Luis Fonsi, Daddy Yankee, Justin Bieber
# 8                             Justin Bieber
# 9                             Justin Bieber
# 10               Camila Cabello, Young Thug
# 11                   The Chainsmokers, Daya
# 12                    The Weeknd, Daft Punk
# 13                        Mike Posner, Seeb
# 14                                 Dua Lipa
# 15                  DJ Snake, Justin Bieber
# 16                               Ed Sheeran
# 17                             James Arthur
# 18                               Ed Sheeran
# 19                           Kendrick Lamar
# ...

# %%
# Connect to database (Note: The package psychopg2 is required for Postgres to work with SQLAlchemy)
engine = sqlalchemy.create_engine("postgresql://postgres:College321!@localhost/Project2")
con = engine.connect()

# Verify that there are no existing tables
print(engine.table_names())
# Out:
# ['test']

# %%
table_name = 'test'
df.to_sql(table_name, con)

# %%
print(engine.table_names())
# Out:
# ['test']

# %%
df1 = pd.DataFrame(columns =['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness','instrumentalness', 'liveness',
                                'valence', 'tempo','type','id','uri','track_href','analysis_url','duration_ms','time_signature' ]) 
df1
# Out:
# Empty DataFrame
# Columns: [danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, id, uri, track_href, analysis_url, duration_ms, time_signature]
# Index: []

# %%
client_id = "1ddd7e32dad24ed58618c27288bba9e4"
client_secret = "e7cd3ce3a90b4b32b787da7ed962340e"

# %%
api_results = []
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API



    

    
for song in song_titles:
    name = song
    result = sp.search(name) #search query
    track_id = result['tracks']['items'][0]['id']
    result2 = sp.audio_features(track_id)
    result3 = result2[0]
    api_results.append(result3)

# %%
api_results[0]
# Out:
# {'danceability': 0.825,
#  'energy': 0.652,
#  'key': 1,
#  'loudness': -3.183,
#  'mode': 0,
#  'speechiness': 0.0802,
#  'acousticness': 0.581,
#  'instrumentalness': 0,
#  'liveness': 0.0931,
#  'valence': 0.931,
#  'tempo': 95.977,
#  'type': 'audio_features',
#  'id': '7qiZfU4dY1lWllzX7mPBI3',
#  'uri': 'spotify:track:7qiZfU4dY1lWllzX7mPBI3',
#  'track_href': 'https://api.spotify.com/v1/tracks/7qiZfU4dY1lWllzX7mPBI3',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7qiZfU4dY1lWllzX7mPBI3',
#  'duration_ms': 233713,
#  'time_signature': 4}

# %%
df1 = pd.DataFrame(columns =['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness','instrumentalness', 'liveness',
                                'valence', 'tempo','type','id','uri','track_href','analysis_url','duration_ms','time_signature' ]) 

df1

df1
# Out:
# Empty DataFrame
# Columns: [danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, id, uri, track_href, analysis_url, duration_ms, time_signature]
# Index: []

# %%
output = df1.append(api_results[0], ignore_index=True)
output1 = output.append(api_results[1], ignore_index=True)
output2 = output1.append(api_results[2], ignore_index=True)
output3 = output2.append(api_results[3], ignore_index=True)
output4 = output3.append(api_results[4], ignore_index=True)
output5 = output4.append(api_results[5], ignore_index=True)
output6 = output5.append(api_results[6], ignore_index=True)
output7 = output6.append(api_results[7], ignore_index=True)
output8 = output7.append(api_results[8], ignore_index=True)
output9 = output8.append(api_results[9], ignore_index=True)
output10 = output9.append(api_results[10], ignore_index=True)
output11 = output10.append(api_results[11], ignore_index=True)
output12 = output11.append(api_results[12], ignore_index=True)
output13 = output12.append(api_results[13], ignore_index=True)
output14 = output13.append(api_results[14], ignore_index=True)
output15 = output14.append(api_results[15], ignore_index=True)
output16 = output15.append(api_results[16], ignore_index=True)
output17 = output16.append(api_results[17], ignore_index=True)
output18 = output17.append(api_results[18], ignore_index=True)
output19 = output18.append(api_results[19], ignore_index=True)
output20 = output19.append(api_results[20], ignore_index=True)
output21 = output20.append(api_results[21], ignore_index=True)
output22 = output21.append(api_results[22], ignore_index=True)
output23 = output22.append(api_results[23], ignore_index=True)
output24 = output23.append(api_results[24], ignore_index=True)
output25 = output24.append(api_results[25], ignore_index=True)
output26 = output25.append(api_results[26], ignore_index=True)
output27 = output26.append(api_results[27], ignore_index=True)
output28 = output27.append(api_results[28], ignore_index=True)
output29 = output28.append(api_results[29], ignore_index=True)
output30 = output29.append(api_results[30], ignore_index=True)
output31 = output30.append(api_results[31], ignore_index=True)
output32 = output31.append(api_results[32], ignore_index=True)
output33 = output32.append(api_results[33], ignore_index=True)
output34 = output33.append(api_results[34], ignore_index=True)
output35 = output34.append(api_results[35], ignore_index=True)
output36 = output35.append(api_results[36], ignore_index=True)
output37 = output36.append(api_results[37], ignore_index=True)
output38 = output37.append(api_results[38], ignore_index=True)
output39 = output38.append(api_results[39], ignore_index=True)
output40 = output39.append(api_results[40], ignore_index=True)
output41 = output40.append(api_results[41], ignore_index=True)
output42 = output41.append(api_results[42], ignore_index=True)
output43 = output42.append(api_results[43], ignore_index=True)
output44 = output43.append(api_results[44], ignore_index=True)
output45 = output44.append(api_results[45], ignore_index=True)
output46 = output45.append(api_results[46], ignore_index=True)
output47 = output46.append(api_results[47], ignore_index=True)
output48 = output47.append(api_results[48], ignore_index=True)
output49 = output48.append(api_results[49], ignore_index=True)
output50 = output49.append(api_results[50], ignore_index=True)
output51 = output50.append(api_results[51], ignore_index=True)
output52 = output51.append(api_results[52], ignore_index=True)
output53 = output52.append(api_results[53], ignore_index=True)
output54 = output53.append(api_results[54], ignore_index=True)
output55 = output54.append(api_results[55], ignore_index=True)
output56 = output55.append(api_results[56], ignore_index=True)
output57 = output56.append(api_results[57], ignore_index=True)
output58 = output57.append(api_results[58], ignore_index=True)
output59 = output58.append(api_results[59], ignore_index=True)
output60 = output59.append(api_results[60], ignore_index=True)
output61 = output60.append(api_results[61], ignore_index=True)
output62 = output61.append(api_results[62], ignore_index=True)
output63 = output62.append(api_results[63], ignore_index=True)
output64 = output63.append(api_results[64], ignore_index=True)
output65 = output64.append(api_results[65], ignore_index=True)
output66 = output65.append(api_results[66], ignore_index=True)
output67 = output66.append(api_results[67], ignore_index=True)
output68 = output67.append(api_results[68], ignore_index=True)
output69 = output68.append(api_results[69], ignore_index=True)
output70 = output69.append(api_results[70], ignore_index=True)
output71 = output70.append(api_results[71], ignore_index=True)
output72 = output71.append(api_results[72], ignore_index=True)
output73 = output72.append(api_results[73], ignore_index=True)
output74 = output73.append(api_results[74], ignore_index=True)
output75 = output74.append(api_results[75], ignore_index=True)
output76 = output75.append(api_results[76], ignore_index=True)
output77 = output76.append(api_results[77], ignore_index=True)
output78 = output77.append(api_results[78], ignore_index=True)
output79 = output78.append(api_results[79], ignore_index=True)
output80 = output79.append(api_results[80], ignore_index=True)
output81 = output80.append(api_results[81], ignore_index=True)
output82 = output81.append(api_results[82], ignore_index=True)
output83 = output82.append(api_results[83], ignore_index=True)
output84 = output83.append(api_results[84], ignore_index=True)
output85 = output84.append(api_results[85], ignore_index=True)
output86 = output85.append(api_results[86], ignore_index=True)
output87 = output86.append(api_results[87], ignore_index=True)
output88 = output87.append(api_results[88], ignore_index=True)
output89 = output88.append(api_results[89], ignore_index=True)
output90 = output89.append(api_results[90], ignore_index=True)
output91 = output90.append(api_results[91], ignore_index=True)
output92 = output91.append(api_results[92], ignore_index=True)
output93 = output92.append(api_results[93], ignore_index=True)
output94 = output93.append(api_results[94], ignore_index=True)
output95 = output94.append(api_results[95], ignore_index=True)
output96 = output95.append(api_results[96], ignore_index=True)
output97 = output96.append(api_results[97], ignore_index=True)
output98 = output97.append(api_results[98], ignore_index=True)
output99 = output98.append(api_results[99], ignore_index=True)

# %%
output99
# Out:
#     danceability  energy key  loudness mode  speechiness  acousticness  \
# 0          0.825   0.652   1    -3.183    0       0.0802      0.581000
# 1          0.796   0.610   1    -5.857    1       0.0516      0.008420
# 2          0.748   0.524   8    -5.599    1       0.0338      0.414000
# 3          0.587   0.535   5    -6.090    0       0.0898      0.117000
# 4          0.781   0.445   2    -6.061    1       0.0295      0.474000
# 5          0.723   0.809   7    -3.081    0       0.0625      0.003460
# 6          0.754   0.449   7    -9.211    1       0.1090      0.033200
# 7          0.653   0.816   2    -4.353    1       0.1670      0.228000
# 8          0.607   0.376   4    -9.954    1       0.4530      0.856000
# 9          0.705   0.640  11    -6.928    0       0.2250      0.023700
# 10         0.765   0.523   2    -4.333    1       0.0300      0.184000
# 11         0.534   0.868  11    -5.057    1       0.2060      0.190000
# ...

# %%
 API_RESULTS_DF =output99

# %%
API_RESULTS_DF
# Out:
#     danceability  energy key  loudness mode  speechiness  acousticness  \
# 0          0.825   0.652   1    -3.183    0       0.0802      0.581000
# 1          0.796   0.610   1    -5.857    1       0.0516      0.008420
# 2          0.748   0.524   8    -5.599    1       0.0338      0.414000
# 3          0.587   0.535   5    -6.090    0       0.0898      0.117000
# 4          0.781   0.445   2    -6.061    1       0.0295      0.474000
# 5          0.723   0.809   7    -3.081    0       0.0625      0.003460
# 6          0.754   0.449   7    -9.211    1       0.1090      0.033200
# 7          0.653   0.816   2    -4.353    1       0.1670      0.228000
# 8          0.607   0.376   4    -9.954    1       0.4530      0.856000
# 9          0.705   0.640  11    -6.928    0       0.2250      0.023700
# 10         0.765   0.523   2    -4.333    1       0.0300      0.184000
# 11         0.534   0.868  11    -5.057    1       0.2060      0.190000
# ...

# %%
final_df = df_songs_artists.join(API_RESULTS_DF)
final_df
# Out:
#                                      Artist  \
# 0                                Ed Sheeran
# 1                       Drake, WizKid, Kyla
# 2                  The Chainsmokers, Halsey
# 3                    Post Malone, 21 Savage
# 4                                Ed Sheeran
# 5                 Major Lazer, MØ, DJ Snake
# 6                                     Drake
# 7   Luis Fonsi, Daddy Yankee, Justin Bieber
# 8                             Justin Bieber
# 9                             Justin Bieber
# 10               Camila Cabello, Young Thug
# 11                   The Chainsmokers, Daya
# 12                    The Weeknd, Daft Punk
# 13                        Mike Posner, Seeb
# 14                                 Dua Lipa
# 15                  DJ Snake, Justin Bieber
# 16                               Ed Sheeran
# 17                             James Arthur
# 18                               Ed Sheeran
# 19                           Kendrick Lamar
# ...

# %%
table_name = 'final'
final_df.to_sql(table_name, con)

# %%
print(engine.table_names())
# Out:
# ['test', 'final']
